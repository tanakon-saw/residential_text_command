# %%
#define configuration for dataset generation
room = ['ห้องนั่งเล่น','ห้องครัว','ห้องนอน','ห้องน้ำ','ห้องรับประทานอาหาร','ห้องสมุด','ห้องพักผู้มาเยือน','ห้องเล่นเกม','ห้องซักผ้า','ระเบียง','ไม่มีห้อง']
device = ['ไฟ']
turn = ['ปิด','เปิด']
scene = ['ซีน เอ','ซีน บี','ซีน ซี','ซีน ดี','ซีน อี','ซีน เอฟ','ซีน จี','ซีน เอช','ไม่มีซีน']
hour = list(range(0,24))
minute = list(range(0,60))

minute_in_thai = ['ศูนย์','หนึ่ง','สอง','สาม','สี่','ห้า','หก','เจ็ด','แปด','เก้า','สิบ','สิบเอ็ด','สิบสอง','สิบสาม','สิบสี่','สิบห้า','สิบหก','สิบเจ็ด','สิบแปด','สิบเก้า','ยี่สิบ','ยี่สิบเอ็ด','ยี่สิบสอง','ยี่สิบสาม','ยี่สิบสี่','ยี่สิบห้า','ยี่สิบหก' ,'ยี่สิบเจ็ด' ,'ยี่สิบแปด','ยี่สิบเก้า','สามสิบ',
'สามสิบเอ็ด','สามสิบสอง','สามสิบสาม','สามสิบสี่','สามสิบห้า','สามสิบหก','สามสิบเจ็ด','สามสิบแปด','สามสิบเก้า','สี่สิบ','สี่สิบเอ็ด','สี่สิบสอง','สี่สิบสาม','สี่สิบสี่','สี่สิบห้า','สี่สิบหก','สี่สิบเจ็ด','สี่สิบแปด','สี่สิบเก้า','ห้าสิบ','ห้าสิบเอ็ด','ห้าสิบสอง',
'ห้าสิบสาม','ห้าสิบสี่''ห้าสิบห้า','ห้าสิบหก','ห้าสิบเจ็ด','ห้าสิบแปด','ห้าสิบเก้า','หกสิบ']
tee_in_thai = ['ตีหนึ่ง','ตีสอง','ตีสาม','ตีสี่','ตีห้า']
mong_in_thai = [ 'หกโมง','เจ็ดโมง','แปดโมง','เก้าโมง','สิบโมง','สิบเอ็ดโมง','ห้าโมง', 'หกโมงเช้า','เจ็ดโมงเช้า','แปดโมงเช้า','เก้าโมงเช้า','สิบโมงเช้า','สิบเอ็ดโมงเช้า','ห้าโมงเย็น','สี่โมงเย็น','หกโมงเย็น']
thaing_in_thai = ['เที่ยงวัน','เที่ยงคืน']
bai_in_thai = ['บ่ายโมง','บ่ายสอง','บ่ายสาม','บ่ายสี่']
tom_in_thai = ['หนึ่งทุ่ม','สองทุ่ม','สามทุ่ม','สี่ทุ่ม','ห้าทุ่ม']

prep_time_in_thai = ['ตอน','เวลา']

tee_dict = {
    'ตีหนึ่ง' : 1,'ตีสอง':2,'ตีสาม':3,'ตีสี่':4,'ตีห้า':5
}
mong_dict = {
    'หกโมง':6,'เจ็ดโมง':7,'แปดโมง':8,'เก้าโมง':9,'สิบโมง':10,'สิบเอ็ดโมง':11,'ห้าโมง':17,'สี่โมง':16,
    'หกโมงเช้า':6,'เจ็ดโมงเช้า':7,'แปดโมงเช้า':8,'เก้าโมงเช้า':9,'สิบโมงเช้า':10,'สิบเอ็ดโมงเช้า':11,'ห้าโมงเย็น':17,'สี่โมงเย็น':16,'หกโมงเย็น':18
}
thaing_dict = {
    'เที่ยงวัน':12,'เที่ยงคืน':0
}
bai_dict = {
   'บ่ายโมง':13,'บ่ายสอง':14,'บ่ายสาม':15,'บ่ายสี่':16
}
tom_dict = {
   'หนึ่งทุ่ม':19,'สองทุ่ม':20,'สามทุ่ม':21,'สี่ทุ่ม':22,'ห้าทุ่ม':23
}

room_dict = {
    'ห้องนั่งเล่น': 'Living Room','ห้องครัว':'Kitchen','ห้องนอน':'Bedroom','ห้องน้ำ':'Bathroom','ห้องรับประทานอาหาร': 'Dining Room','ห้องสมุด': 'Library','ห้องพักผู้มาเยือน': 'Guest Room','ห้องเล่นเกม':'Game Room','ห้องซักผ้า':'Laundry Room','ระเบียง':'balcony','ไม่มีห้อง':'no room'
}

scene_dict = {
    'ซีน เอ':'scene A','ซีน บี':'scene B','ซีน ซี':'scene C','ซีน ดี':'scene D','ซีน อี':'scene E','ซีน เอฟ':'scene F','ซีน จี':'scene G','ซีน เอช':'scene H','ไม่มีซีน':'no scene'
}

# %%
# for detect invalid text
irregular = ['ดอกไม้','กองทัพ','กล้วย','ทะเล','ฟ้า','ดวงจันทร์','ฝน','ปลา','ความรัก','เพลง','หนังสือ','หิมะ','อาหาร','เสียง','มือถือ','คอมพิวเตอร์','โต๊ะ','เก้าอี้',
'โทรทัศน์','สวน','ชายหาด','ดอกไม้ป่า','ควันไฟ','ชาวนา','ป่า','แมว','หมา','ช้าง','เสือ','ม้า','กระต่าย','จระเข้','สิงโต','สัตว์ป่า','นก','ปลาบนบก','หมู','วัว',
'ม้าน้ำ','ปลาสลิด','หอย','ปู','กุ้ง','ปลาหมึก','หมู่บ้าน','สำนักงาน','โรงเรียน','โรงพยาบาล','ตึกสูง','ไงฟฟฉต','พญตาขรว','รกำวาลอิ','กทุวาอรพ','คขคะนาจ','วไลชอบข','น้ำปนต่','ยิมกุดเพย','ดาลยิวะพ',
'และกักอุ','ฉัยบานีพ','แจ้งอสยถ','สักษมดาห','อุรหูยะท','ญญาด่หคะ','ฆ้อยฤกั','พหุกนาฎจ','หะแล้วลำ',
'กว่านักมา','สิงทอดเพลิ','รื้อล้มว่น','ถอยพรุนจะ','ตาลิตะบอ','แสนสว่างดุ','ทริปเปอร์ฟ',
'ศรัญญาอึ','นอกจากแล้','ศุขัณฑ์ป','ธรรมราษฎร','ทุกความสา','คลั่งมีคำ','ดั่งกาสะ','หินปูนทราย',
'ทวิภาคเนื้อ','บอกจริงหรอ','ดังฟังใจ','แจ้งเรื่อยรา','สำราลักษณ์','กลับบ้านทัน','กล่อมความคิด','ไร้ความหมาย',
'บ่นเพราะจะ','อัดแน่นเต็ม','รุ้งสายอัป','สดชื่นไปทุก','จุดเริ่มต้นใหม่','ลงตัวเต็มที่',
'ศิลปินอินดีแล','ซึ้งซาบซึ้ง','สุดเสียงหลอกลวง']

# %%
# for debug
def print_input(input,label):
  for i,w in enumerate(input):
    print(i,w,label[i])

# %%
normal_room_case = []
normal_room_label = []
valid = 1
is_scene = 0
has_num = 0
hour = -1
minute = -1

# normal_room_case
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(room):
      valid = 1
      text = verb+obj1+obj2
      normal_room_case.append(text)

      if obj2 == 'ไม่มีห้อง':
        valid = 0
      normal_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# print_input(normal_room_case,normal_room_label)

# %%
normal_scene_case = []
normal_scene_label = []
valid = 1
is_scene = 1
has_num = 0
hour = -1
minute = -1

# normal_scene_label
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(scene):
      valid = 1
      text = verb+obj1+obj2
      normal_scene_case.append(text)

      if obj2 == 'ไม่มีซีน':
        valid = 0
      normal_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# print_input(normal_scene_case,normal_scene_label)

# %%
irregular_room_case = []
irregular_room_label = []
valid = 0
is_scene = 0
has_num = 0
hour = -1
minute = -1

# irregular_room_case
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      text = verb+obj1+obj2
      irregular_room_case.append(text)
      irregular_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# for i_1,verb in enumerate(turn):
#   for i_2,obj1 in enumerate(irregular):
#     for i_3,obj2 in enumerate(room):
#       text = verb+obj1+obj2
#       irregular_room_case.append(text)
#       irregular_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# for i_1,verb in enumerate(irregular):
#   for i_2,obj1 in enumerate(device):
#     for i_3,obj2 in enumerate(room):
#       text = verb+obj1+obj2
#       irregular_room_case.append(text)
#       irregular_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])


# print_input(irregular_room_case,irregular_room_label)

# %%
irregular_scene_case = []
irregular_scene_label = []
valid = 0
is_scene = 1
has_num = 0
hour = -1
minute = -1

# irregular_scene_case
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      text = verb+obj1+obj2
      irregular_scene_case.append(text)
      irregular_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# for i_1,verb in enumerate(turn):
#   for i_2,obj1 in enumerate(irregular):
#     for i_3,obj2 in enumerate(scene):
#       text = verb+obj1+obj2
#       irregular_scene_case.append(text)
#       irregular_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# for i_1,verb in enumerate(irregular):
#   for i_2,obj1 in enumerate(device):
#     for i_3,obj2 in enumerate(scene):
#       text = verb+obj1+obj2
#       irregular_scene_case.append(text)
#       irregular_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])


# print_input(irregular_scene_case,irregular_scene_label)

# %%
time_room_case = []
time_room_label = []
valid = 1
is_scene = 0
has_num = 1
hour = -1
minute = -1
 
# time_room_case tee
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(room):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(tee_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_room_case.append(text)

            if obj2 == 'ไม่มีห้อง':
              valid = 0

            hour = tee_dict[obj4]
            minute = i_6
            time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_room_case mong
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(room):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(mong_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_room_case.append(text)

            if obj2 == 'ไม่มีห้อง':
              valid = 0

            hour = mong_dict[obj4]
            minute = i_6
            time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_room_case thaing
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(room):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(thaing_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_room_case.append(text)

            if obj2 == 'ไม่มีห้อง':
              valid = 0

            hour = thaing_dict[obj4]
            minute = i_6
            time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_room_case bai
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(room):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(bai_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_room_case.append(text)

            if obj2 == 'ไม่มีห้อง':
              valid = 0

            hour = bai_dict[obj4]
            minute = i_6
            time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_room_case tom
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(room):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(tom_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_room_case.append(text)

            if obj2 == 'ไม่มีห้อง':
              valid = 0

            hour = tom_dict[obj4]
            minute = i_6
            time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# print_input(time_room_case,time_room_label)

# %%
time_scene_case = []
time_scene_label = []
valid = 1
is_scene = 1
has_num = 1
hour = -1
minute = -1
 
# time_scene_case tee
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(scene):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(tee_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_scene_case.append(text)

            if obj2 == 'ไม่มีซีน':
              valid = 0

            hour = tee_dict[obj4]
            minute = i_6
            time_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_scene_case mong
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(scene):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(mong_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_scene_case.append(text)

            if obj2 == 'ไม่มีซีน':
              valid = 0

            hour = mong_dict[obj4]
            minute = i_6
            time_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_scene_case thaing
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(scene):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(thaing_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_scene_case.append(text)

            if obj2 == 'ไม่มีซีน':
              valid = 0

            hour = thaing_dict[obj4]
            minute = i_6
            time_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_scene_case bai
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(scene):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(bai_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_scene_case.append(text)

            if obj2 == 'ไม่มีซีน':
              valid = 0

            hour = bai_dict[obj4]
            minute = i_6
            time_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# time_scene_case tom
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(scene):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(tom_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            valid = 1
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            time_scene_case.append(text)

            if obj2 == 'ไม่มีซีน':
              valid = 0

            hour = tom_dict[obj4]
            minute = i_6
            time_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# print_input(time_scene_case,time_scene_label)

# %%
irregular_time_room_case = []
irregular_time_room_label = []
valid = 0
is_scene = 0
has_num = 0
hour = -1
minute = -1

# irregular_scene_case
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      text = verb+obj1+obj2
      irregular_scene_case.append(text)
      irregular_scene_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# irregular_time_room_case tee
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(tee_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            irregular_time_room_case.append(text)

            hour = tee_dict[obj4]
            minute = i_6
            irregular_time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# irregular_time_room_case mong
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(mong_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            irregular_time_room_case.append(text)

            hour = mong_dict[obj4]
            minute = i_6
            irregular_time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# irregular_time_room_case thaing
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(thaing_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            irregular_time_room_case.append(text)

            hour = thaing_dict[obj4]
            minute = i_6
            irregular_time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# irregular_time_room_case bai
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(bai_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            irregular_time_room_case.append(text)

            hour = bai_dict[obj4]
            minute = i_6
            irregular_time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])

# irregular_time_room_case tom
for i_1,verb in enumerate(turn):
  for i_2,obj1 in enumerate(device):
    for i_3,obj2 in enumerate(irregular):
      for i_4,obj3 in enumerate(prep_time_in_thai):
        for i_5,obj4 in enumerate(tom_in_thai):
          for i_6,obj5 in enumerate(minute_in_thai):
            text = verb+obj1+obj2+obj3+obj4+obj5+'นาที'
            irregular_time_room_case.append(text)

            hour = tom_dict[obj4]
            minute = i_6
            irregular_time_room_label.append([valid,is_scene,has_num,i_1,i_2,obj2,hour,minute])



# print_input(irregular_time_room_case,irregular_time_room_label)

# %%
# normal_room_case,normal_room_label
# normal_scene_case,normal_scene_label
# irregular_room_case,irregular_room_label
# irregular_scene_case,irregular_scene_label
# time_room_case,time_room_label
# time_scene_case,time_scene_label
# irregular_time_room_case,irregular_time_room_label

# merge all possible case
all_text = normal_room_case+normal_scene_case+irregular_room_case+irregular_scene_case+time_room_case+time_scene_case+irregular_time_room_case
all_label  = normal_room_label+normal_scene_label+irregular_room_label+irregular_scene_label+time_room_label+time_scene_label+irregular_time_room_label
len(all_text),len(all_label)
# Out:
# (914554, 914554)

# %%
all_text[:5]
# Out:
# ['ปิดไฟห้องนั่งเล่น',
#  'ปิดไฟห้องครัว',
#  'ปิดไฟห้องนอน',
#  'ปิดไฟห้องน้ำ',
#  'ปิดไฟห้องรับประทานอาหาร']

# %%
all_label[:5]
# Out:
# [[1, 0, 0, 0, 0, 'ห้องนั่งเล่น', -1, -1],
#  [1, 0, 0, 0, 0, 'ห้องครัว', -1, -1],
#  [1, 0, 0, 0, 0, 'ห้องนอน', -1, -1],
#  [1, 0, 0, 0, 0, 'ห้องน้ำ', -1, -1],
#  [1, 0, 0, 0, 0, 'ห้องรับประทานอาหาร', -1, -1]]

# %%
zip_data = [[x]+y for x,y in zip(all_text, all_label)]
zip_data[:5]
# Out:
# [['ปิดไฟห้องนั่งเล่น', 1, 0, 0, 0, 0, 'ห้องนั่งเล่น', -1, -1],
#  ['ปิดไฟห้องครัว', 1, 0, 0, 0, 0, 'ห้องครัว', -1, -1],
#  ['ปิดไฟห้องนอน', 1, 0, 0, 0, 0, 'ห้องนอน', -1, -1],
#  ['ปิดไฟห้องน้ำ', 1, 0, 0, 0, 0, 'ห้องน้ำ', -1, -1],
#  ['ปิดไฟห้องรับประทานอาหาร', 1, 0, 0, 0, 0, 'ห้องรับประทานอาหาร', -1, -1]]

# %%
import pandas as pd

df = pd.DataFrame(zip_data,columns = ['text','valid','is_scene','has_num','turn_on_off','device','env','hour','minute'])
df.head()
# Out:
#                       text  valid  is_scene  has_num  turn_on_off  device  \
# 0        ปิดไฟห้องนั่งเล่น      1         0        0            0       0
# 1            ปิดไฟห้องครัว      1         0        0            0       0
# 2             ปิดไฟห้องนอน      1         0        0            0       0
# 3             ปิดไฟห้องน้ำ      1         0        0            0       0
# 4  ปิดไฟห้องรับประทานอาหาร      1         0        0            0       0
#
#                   env  hour  minute
# 0        ห้องนั่งเล่น    -1      -1
# 1            ห้องครัว    -1      -1
# 2             ห้องนอน    -1      -1
# 3             ห้องน้ำ    -1      -1
# 4  ห้องรับประทานอาหาร    -1      -1

# %%
df.to_csv('residual_text_data.csv', index=False)
